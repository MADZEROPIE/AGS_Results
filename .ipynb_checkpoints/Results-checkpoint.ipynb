# %% [markdown]
# # Пример работы многошаговой адаптивной схемы

# %% [markdown]
# Глобальная оценка константы Липшица
# ![image.png](attachment:image.png)

# %% [markdown]
# Адаптивная оценка константы Липшица
# ![image.png](attachment:image.png)

# %% [markdown]
# # Серии задач

# %% [markdown]
# ## 1. Функции Гришагина

# %% [markdown]
# **Остановка по попаданию в окрестность**
# **R = 2. N = 800**
# ![GRISH_GL+AD.png](attachment:GRISH_GL+AD.png)
# Синяя - ***Глобальная*** оценка константы Липшица
# Желтая - ***Адаптивная*** оценка константы Липшица

# %% [markdown]
# **N = 650**
# ![image.png](attachment:image.png)
# Синяя - ***Глобальная*** оценка константы Липшица **R = 2**
# Желтая - ***Адаптивная*** оценка константы Липшица **R = 2**
# Красная - ***Инъективная развертка*** **R = 3**

# %% [markdown]
# **Остановка по точности**
# **R = 2.6. N = 800**
# ![GRISH_ACC_r2,6_GL+AD.png](attachment:GRISH_ACC_r2,6_GL+AD.png)
# Синяя - ***Глобальная*** оценка константы Липшица
# Желтая - ***Адаптивная*** оценка константы Липшица

# %% [markdown]
# **R = 3. N = 1200**
# ![GRISH_ACC_r3_GL+AD+INJ.png](attachment:GRISH_ACC_r3_GL+AD+INJ.png)
# Синяя - ***Глобальная*** оценка константы Липшица
# Желтая - ***Адаптивная*** оценка константы Липшица
# Красная - ***Инъективная развертка***

# %% [markdown]
# ## 2. GKLS Simple

# %% [markdown]
# **Остановка по попаданию в окрестность**
# **R = 3. N = 800**
# ![GKLS_S_r3_GL+AD.png](attachment:GKLS_S_r3_GL+AD.png)
# Синяя - ***Глобальная*** оценка константы Липшица
# Желтая - ***Адаптивная*** оценка константы Липшица

# %% [markdown]
# **Остановка по точности**
# **R = 3. N = 1000**
# ![GKLS_S_ACC_r3_GL+AD.png](attachment:GKLS_S_ACC_r3_GL+AD.png)
# Синяя - ***Глобальная*** оценка константы Липшица
# Желтая - ***Адаптивная*** оценка константы Липшица

# %% [markdown]
# ## 3. GKLS Hard

# %% [markdown]
# **Остановка по попаданию в окрестность**
# **R = 5. N = 3100**
# ![GKLS_H_r5_GL+AD.png](attachment:GKLS_H_r5_GL+AD.png)
# Синяя - ***Глобальная*** оценка константы Липшица
# Желтая - ***Адаптивная*** оценка константы Липшица

# %% [markdown]
# **Остановка по точности**
# **N = 4100**
# ![GKLS_H_ACC_GL+AD+GL.png](attachment:GKLS_H_ACC_GL+AD+GL.png)
# Синяя - ***Глобальная*** оценка константы Липшица **R = 5.5**
# Желтая - ***Адаптивная*** оценка константы Липшица **R = 5.5**
# Красная - ***Глобальная*** оценка константы Липшица **R = 4.5**

# %% [markdown]
# # Дополнительные задачи

# %% [markdown]
# ## 1. Вытянутый параболоид 1

# %% [markdown]
# ### 1.1 По попаданию в окрестность

# %% [markdown]
# **Глобальная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Адартивная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 1.2 По точности

# %% [markdown]
# **Глобальная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Адартивная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 2. Вытянутый параболоид 2

# %% [markdown]
# **Глобальная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Адаптивная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# # 3. Экспоненциальная функция

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.1 По попаданию в окрестность

# %% [markdown]
# **Глобальная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Адаптивная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 3.2 По точности

# %% [markdown]
# **Глобальная оценка**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Адаптивная оценка**
# ![image.png](attachment:image.png)
